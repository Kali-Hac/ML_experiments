# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# write your code here
"""
☆*°☆*°(∩^o^)~━━  2017/12/1 23:55
      (ˉ▽￣～) ~~ 一捆好葱 (软件4班饶浩聪) (*˙︶˙*)☆*°
      Fuction： 机器学习lab2(py2.7代码 不兼容3的地方已注释√ ━━━━━☆*°☆*°
"""
from sklearn.datasets import load_svmlight_file
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random

# Adam
mt_cur = 0.0
mt_pre = 0.0
vt_cur = 0.0
vt_pre = 0.0

vt_curr = np.array([0.0 for i in range(124)])
vt_prev = np.array([0.0 for i in range(124)])

def get_train_data():
	data = load_svmlight_file("9a9_train")
	return data[0], data[1]
def get_test_data():
	data = load_svmlight_file("9a9_test")
	return data[0], data[1]

# f为假设函数，即逻辑回归概率输出函数
def f(x, w):
	return 1.0 / (1.0 + np.exp(-(x.T * w).sum()))

# Y[i] 原本为 +1 -1 要先转换为 +1 0 才能进行计算
def Loss(X, w, Y):
	loss_sum = 0.0
	Size = X.shape[0]
	for i in range(Size):
		if f(X[i], w) == 0 or f(X[i], w) == 1:
			loss_sum += 0
		else:
			loss_sum += -(Y[i] * np.log(f(X[i], w)) + (1 - Y[i]) * np.log(1 - f(X[i], w)))
	return loss_sum

# 同上处理，再计算验证集准确率
def cal_accuracy(w, X_val, y_val):
	right_num = 0
	for i in range(X_val.shape[0]):
		result = f(X_val[i], w)
		if result >= 0.5 and y_val[i] == 1:
			right_num += 1
		if result < 0.5 and y_val[i] == 0:
			right_num += 1
	return float(right_num) / float(X_val.shape[0])

def SGD_change(X_train, y_train, w):
	X_size = X_train.shape[0]
	# 随机梯度下降更新权重w，随机选取1/2样本里的某个样本作为选择起点
	t = random.randint(0, (X_size - 1) // 2)
	# print w
	gradient_sums = np.array([0.0 for i in range(124)])
	n = 0
	for i in range(t, t + (X_size - 1) // 8):
		xx = X_train[i].tolist()
		xx = np.array(list(*xx))
		# print xx
		gradient_sums += (f(X_train[i], w) - y_train[i]) * xx
		n += 1
	return gradient_sums / n

# RMSprop学习参数更新，此函数包含SGD更新的梯度和a，即返回值为更新量
def RMSprop_change(X_train, y_train, w, a):
	global vt_cur, vt_pre
	sgd_change = SGD_change(X_train, y_train, w)
	vt_cur = vt_pre * 0.9 + 0.1 * sgd_change ** 2
	vt_pre = vt_cur
	return a * sgd_change/(np.sqrt(vt_cur) + 10 ** (-8))

# Nesterov accelerated gradient学习参数更新，此函数包含SGD更新的梯度和a，即返回值为更新量
def NAG(X_train, y_train, w, a):
	global vt_curr, vt_prev
	vt_curr = 0.9 * vt_prev + SGD_change(X_train, y_train, w - a * 0.1 * vt_prev)
	vt_prev = vt_curr
	return a * vt_curr


# Adam学习参数更新，此函数包含SGD更新的梯度和a，即返回值为更新量
def Adam_change(X_train, y_train, w, a):
	global mt_cur, mt_pre, vt_cur, vt_pre
	sgd_change = SGD_change(X_train, y_train, w)
	mt_cur = mt_pre * 0.9 + 0.1 * sgd_change
	vt_cur = vt_pre * 0.99 + 0.01 * sgd_change ** 2
	mt_pre = mt_cur
	vt_pre = vt_cur
	return mt_cur/(np.sqrt(vt_cur) + 10 ** (-8)) * a * sgd_change

def Logistic_R(options):
	X_train, y_train = get_train_data()
	# 给X增加一列x0=1
	x0 = np.array([1 for i in range(X_train.shape[0])])
	# 转换为稠密矩阵
	X_train = X_train.todense()
	X_train = np.column_stack((x0, X_train))
	# Y[i] 原本为 +1 -1 要先转换为 +1 0 才能进行计算
	for i in range(y_train.shape[0]):
		if y_train[i] == -1:
			y_train[i] = 0

	X_val, y_val = get_test_data()
	# 给X增加一列x0=1
	x0 = np.array([1 for i in range(X_val.shape[0])])
	# 转换为稠密矩阵
	X_val = X_val.todense()
	X_val = np.column_stack((x0, X_val))
	# Y[i] 原本为 +1 -1 要先转换为 +1 0 才能进行计算
	for i in range(y_val.shape[0]):
		if y_val[i] == -1:
			y_val[i] = 0
	# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=1214)
	# 初始化参数的三种方式，共有123个属性，加上一个偏置b = w0 * x0 (x0 = 1 ) 则为124个分量
	w = np.array([0.0 for i in range(124)])
	# a为学习系数 0.016 0.0016 0.00016, 发现0.0016效果最佳 再试0.0032,0.0064
	a = 0.0010
	# 学习率为0.01时 每次随机取样本为1/10时 最后会在14506~140505之间跌宕，已陷入局部最优
	# 学习率为0.001时 每次随机取样本为1/6时 最后会在14506~140505之间跌宕，已陷入局部最优
	# 学习率为0.001时 每次随机取样本为1/10时 最后会在14506~140505之间跌宕，已陷入局部最优 后两个观察效果比价好
	loss = Loss(X_train, w, y_train)
	cnt = 0
	train_loss = []
	val_loss = []
	while True:
		# 随机梯度下降
		if options == 1:
			w -= SGD_change(X_train, y_train, w) * a
		elif options == 2:
			w -= Adam_change(X_train, y_train, w, a)
		elif options == 3:
			w -= RMSprop_change(X_train, y_train, w, a)
		else:
			w -= NAG(X_train, y_train, w, a)
# 		print cal_accuracy(w, X_val, y_val)
		new_loss = Loss(X_train, w, y_train)
		v_loss = Loss(X_val, w, y_val)
		# 当loss变化幅度小于0.0001时停止
		if abs(loss - new_loss) > 0.0001:
			loss = new_loss
			print ('Train_loss: ' + str(loss))
			print ('Test_loss: ' + str(v_loss))
		else:
			break
		train_loss.append(loss)
		val_loss.append(v_loss)
		cnt += 1
# 当迭代次数大于50时也停止
		if cnt > 35:
			# print('Final: Train_loss = %f, val_loss = %f' % loss, v_loss)
			break
	plt.figure(figsize=(8, 6))
	plt.xlabel('Stochastic gradient descent - Iteration times')
	plt.ylabel('Loss')
	plt.plot(range(cnt), train_loss, 'o-', label=u"Training Set")
	plt.plot(range(cnt), val_loss, 'r-', label=u"Validation set")
	plt.legend()
	plt.grid()
	plt.show()

# %%
Logistic_R(1)  # SGD
# Out:
